# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install base58 && pip3 install cirq.google cirq bitcoin
# Out:
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Installing collected packages: base58
# Successfully installed base58-2.1.1
# Collecting cirq.google
#   Downloading cirq_google-1.6.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting cirq
#   Downloading cirq-1.6.1-py3-none-any.whl.metadata (16 kB)
# Collecting bitcoin
#   Downloading bitcoin-1.1.42.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-api-core~=2.22 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq.google) (2.28.1)
# Requirement already satisfied: proto-plus~=1.25 in /usr/local/lib/python3.12/dist-packages (from cirq.google) (1.26.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.12/dist-packages (from cirq.google) (5.29.5)
# Collecting typedunits (from cirq.google)
#   Downloading typedunits-0.0.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting cirq-core==1.6.1 (from cirq.google)
#   Downloading cirq_core-1.6.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (25.4.0)
# Collecting duet>=0.2.8 (from cirq-core==1.6.1->cirq.google)
#   Downloading duet-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib~=3.8 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (3.10.0)
# Requirement already satisfied: networkx~=3.4 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (3.6.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (2.0.2)
# Requirement already satisfied: pandas~=2.1 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (2.2.2)
# Collecting sortedcontainers~=2.0 (from cirq-core==1.6.1->cirq.google)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy~=1.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (1.16.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (1.14.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (4.15.0)
# Requirement already satisfied: tqdm>=4.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq.google) (4.67.1)
# Collecting cirq-aqt==1.6.1 (from cirq)
#   Downloading cirq_aqt-1.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting cirq-ionq==1.6.1 (from cirq)
#   Downloading cirq_ionq-1.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting cirq-pasqal==1.6.1 (from cirq)
#   Downloading cirq_pasqal-1.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting cirq-web==1.6.1 (from cirq)
#   Downloading cirq_web-1.6.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: requests~=2.32 in /usr/local/lib/python3.12/dist-packages (from cirq-aqt==1.6.1->cirq) (2.32.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (1.72.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq.google) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq.google) (1.71.2)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from typedunits->cirq.google) (3.0.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from typedunits->cirq.google) (3.2.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (4.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq.google) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq.google) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->cirq-core==1.6.1->cirq.google) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq.google) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.8->cirq-core==1.6.1->cirq.google) (1.17.0)
# Downloading cirq_google-1.6.1-py3-none-any.whl (670 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.8/670.8 kB 13.9 MB/s eta 0:00:00
# Downloading cirq_core-1.6.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 52.1 MB/s eta 0:00:00
# Downloading cirq-1.6.1-py3-none-any.whl (11 kB)
# Downloading cirq_aqt-1.6.1-py3-none-any.whl (32 kB)
# Downloading cirq_ionq-1.6.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 6.6 MB/s eta 0:00:00
# Downloading cirq_pasqal-1.6.1-py3-none-any.whl (33 kB)
# Downloading cirq_web-1.6.1-py3-none-any.whl (430 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.5/430.5 kB 34.3 MB/s eta 0:00:00
# Downloading typedunits-0.0.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 70.5 MB/s eta 0:00:00
# Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: bitcoin
#   Building wheel for bitcoin (setup.py) ... done
#   Created wheel for bitcoin: filename=bitcoin-1.1.42-py3-none-any.whl size=44403 sha256=dbe9591d7bd9d81e9023193a71b965cfb66462fa644204b742b61cba92eda1c2
#   Stored in directory: /root/.cache/pip/wheels/ca/58/57/229b3e0dacbfd900c21be9010d6b138ec314fe91f57e973183
# Successfully built bitcoin
# Installing collected packages: sortedcontainers, bitcoin, typedunits, duet, cirq-core, cirq-web, cirq-pasqal, cirq-ionq, cirq-aqt, cirq.google, cirq
# Successfully installed bitcoin-1.1.42 cirq-1.6.1 cirq-aqt-1.6.1 cirq-core-1.6.1 cirq-ionq-1.6.1 cirq-pasqal-1.6.1 cirq-web-1.6.1 cirq.google-1.6.1 duet-0.2.9 sortedcontainers-2.4.0 typedunits-0.0.1

# %%
# !pip3 install cirq_google
# Out:
# Requirement already satisfied: cirq_google in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: google-api-core~=2.22 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq_google) (2.28.1)
# Requirement already satisfied: proto-plus~=1.25 in /usr/local/lib/python3.12/dist-packages (from cirq_google) (1.26.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.12/dist-packages (from cirq_google) (5.29.5)
# Requirement already satisfied: typedunits in /usr/local/lib/python3.12/dist-packages (from cirq_google) (0.0.1)
# Requirement already satisfied: cirq-core==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq_google) (1.6.1)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (25.4.0)
# Requirement already satisfied: duet>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (0.2.9)
# Requirement already satisfied: matplotlib~=3.8 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (3.10.0)
# Requirement already satisfied: networkx~=3.4 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (3.6.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (2.0.2)
# Requirement already satisfied: pandas~=2.1 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (2.2.2)
# Requirement already satisfied: sortedcontainers~=2.0 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (2.4.0)
# Requirement already satisfied: scipy~=1.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (1.16.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (1.14.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (4.15.0)
# Requirement already satisfied: tqdm>=4.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq_google) (4.67.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (1.72.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (2.43.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq_google) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq_google) (1.71.2)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from typedunits->cirq_google) (3.0.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from typedunits->cirq_google) (3.2.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (4.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq_google) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq_google) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->cirq-core==1.6.1->cirq_google) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq_google) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.8->cirq-core==1.6.1->cirq_google) (1.17.0)

# %%
# !pip install base58 && pip3 install parameters && pip3 install Crypto && pip install pycryptodome && pip install Cryptography && pip install bitcoin && pip install ecdsa
# Out:
# Requirement already satisfied: base58 in /usr/local/lib/python3.12/dist-packages (2.1.1)
# Collecting parameters
#   Downloading parameters-0.2.1.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: parameters
#   Building wheel for parameters (setup.py) ... done
#   Created wheel for parameters: filename=parameters-0.2.1-py3-none-any.whl size=24747 sha256=9406f03724d7a87dc5a2acc62d2f6fc8da25275a1e98cf8d81d4402976d3f561
#   Stored in directory: /root/.cache/pip/wheels/b6/16/2f/901678771468ce601db89016cf0aa3fbaa690ce3af70b37a1a
# Successfully built parameters
# Installing collected packages: parameters
# Successfully installed parameters-0.2.1
# Collecting Crypto
#   Downloading crypto-1.4.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting Naked (from Crypto)
#   Downloading Naked-0.1.32-py2.py3-none-any.whl.metadata (931 bytes)
# Collecting shellescape (from Crypto)
#   Downloading shellescape-3.8.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from Naked->Crypto) (2.32.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from Naked->Crypto) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (2025.11.12)
# Downloading crypto-1.4.1-py2.py3-none-any.whl (18 kB)
# Downloading Naked-0.1.32-py2.py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 kB 10.6 MB/s eta 0:00:00
# Downloading shellescape-3.8.1-py2.py3-none-any.whl (3.1 kB)
# Installing collected packages: shellescape, Naked, Crypto
# Successfully installed Crypto-1.4.1 Naked-0.1.32 shellescape-3.8.1
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.1 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0
# Requirement already satisfied: Cryptography in /usr/local/lib/python3.12/dist-packages (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from Cryptography) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->Cryptography) (2.23)
# Requirement already satisfied: bitcoin in /usr/local/lib/python3.12/dist-packages (1.1.42)
# Collecting ecdsa
#   Downloading ecdsa-0.19.1-py2.py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from ecdsa) (1.17.0)
# Downloading ecdsa-0.19.1-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: ecdsa
# Successfully installed ecdsa-0.19.1

# %%
# !pip install qiskit_ibm_runtime && pip install qiskit==0.24.0
# Out:
# Collecting qiskit_ibm_runtime
#   Downloading qiskit_ibm_runtime-0.44.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.0.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Downloading ibm_platform_services-0.72.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.12.3)
# Collecting qiskit>=1.4.1 (from qiskit_ibm_runtime)
#   Downloading qiskit-2.2.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (25.0)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.17.0)
# Collecting rustworkx>=0.15.0 (from qiskit>=1.4.1->qiskit_ibm_runtime)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit>=1.4.1->qiskit_ibm_runtime)
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit_ibm_runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit_ibm_runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit_ibm_runtime) (2025.11.12)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (43.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading pyspnego-0.12.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.10.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.23)
# Downloading qiskit_ibm_runtime-0.44.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.4 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.72.0-py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.5/378.5 kB 28.9 MB/s eta 0:00:00
# Downloading qiskit-2.2.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 100.4 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 5.9 MB/s eta 0:00:00
# Downloading pyspnego-0.12.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.8 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.8 MB/s eta 0:00:00
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit, ibm_cloud_sdk_core, pyspnego, ibm-platform-services, requests-ntlm, qiskit_ibm_runtime
# Successfully installed ibm-platform-services-0.72.0 ibm_cloud_sdk_core-3.24.2 pyspnego-0.12.0 qiskit-2.2.3 qiskit_ibm_runtime-0.44.0 requests-ntlm-1.3.0 rustworkx-0.17.1 stevedore-5.6.0
# Collecting qiskit==0.24.0
#   Downloading qiskit-0.24.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-terra==0.16.4 (from qiskit==0.24.0)
#   Downloading qiskit-terra-0.16.4.tar.gz (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting qiskit-aer==0.7.6 (from qiskit==0.24.0)
#   Downloading qiskit-aer-0.7.6.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 105.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install utils && pip install bitarray && pip3 install tolist
# Out:
# Collecting utils
#   Downloading utils-1.0.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utils
#   Building wheel for utils (setup.py) ... done
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=dbf036cf6f24cd90a582f52d7e686e40a4feb651ea9eabb244f2c6482ca79dfc
#   Stored in directory: /root/.cache/pip/wheels/b6/a1/81/1036477786ae0e17b522f6f5a838f9bc4288d1016fc5d0e1ec
# Successfully built utils
# Installing collected packages: utils
# Successfully installed utils-1.0.2
# Collecting bitarray
#   Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: bitarray
# Successfully installed bitarray-3.8.0
# Collecting tolist
#   Downloading tolist-0.0.post0.tar.gz (670 bytes)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install --upgrade cirq
# Out:
# Requirement already satisfied: cirq in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: cirq-aqt==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-core==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-google==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-ionq==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-pasqal==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-web==1.6.1 in /usr/local/lib/python3.12/dist-packages (from cirq) (1.6.1)
# Requirement already satisfied: requests~=2.32 in /usr/local/lib/python3.12/dist-packages (from cirq-aqt==1.6.1->cirq) (2.32.4)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (25.4.0)
# Requirement already satisfied: duet>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (0.2.9)
# Requirement already satisfied: matplotlib~=3.8 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (3.10.0)
# Requirement already satisfied: networkx~=3.4 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (3.6.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (2.0.2)
# Requirement already satisfied: pandas~=2.1 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (2.2.2)
# Requirement already satisfied: sortedcontainers~=2.0 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (2.4.0)
# Requirement already satisfied: scipy~=1.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (1.16.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (1.14.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (4.15.0)
# Requirement already satisfied: tqdm>=4.12 in /usr/local/lib/python3.12/dist-packages (from cirq-core==1.6.1->cirq) (4.67.1)
# Requirement already satisfied: google-api-core~=2.22 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (2.28.1)
# Requirement already satisfied: proto-plus~=1.25 in /usr/local/lib/python3.12/dist-packages (from cirq-google==1.6.1->cirq) (1.26.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.12/dist-packages (from cirq-google==1.6.1->cirq) (5.29.5)
# Requirement already satisfied: typedunits in /usr/local/lib/python3.12/dist-packages (from cirq-google==1.6.1->cirq) (0.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.72.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.71.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.1->cirq-core==1.6.1->cirq) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->cirq-core==1.6.1->cirq) (1.3.0)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from typedunits->cirq-google==1.6.1->cirq) (3.0.12)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (4.9.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (0.6.1)

# %%
# !pip3 install bit && pip3 install ice && pip3 install argparse && pip3 install base58 && pip3 install bitcoin && pip3 install pub && pip3 install requests && pip3 install ctypes
# Out:
# Collecting bit
#   Downloading bit-0.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting coincurve>=4.3.0 (from bit)
#   Downloading coincurve-21.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bit) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (2025.11.12)
# Downloading bit-0.8.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 2.4 MB/s eta 0:00:00
# Downloading coincurve-21.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.5 MB/s eta 0:00:00
# Installing collected packages: coincurve, bit
# Successfully installed bit-0.8.0 coincurve-21.0.0
# Collecting ice
#   Downloading ice-0.0.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ice
#   Building wheel for ice (setup.py) ... done
#   Created wheel for ice: filename=ice-0.0.2-py3-none-any.whl size=11664 sha256=b32afea2c3625195c0508f892a1d950626c965873494a1617442f7015601126a
#   Stored in directory: /root/.cache/pip/wheels/47/ab/d4/d73ad9aae95714c1c1a0778b6a469216f15d68d89f2e93605b
# Successfully built ice
# Installing collected packages: ice
# Successfully installed ice-0.0.2
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: base58 in /usr/local/lib/python3.12/dist-packages (2.1.1)
# Requirement already satisfied: bitcoin in /usr/local/lib/python3.12/dist-packages (1.1.42)
# Collecting pub
#   Downloading pub-0.0.4.tar.gz (6.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting path.py>=2.2 (from pub)
#   Downloading path.py-12.5.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting envoy>=0.0.2 (from pub)
#   Downloading envoy-0.0.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: networkx>=1.6 in /usr/local/lib/python3.12/dist-packages (from pub) (3.6.1)
# Collecting path (from path.py>=2.2->pub)
#   Downloading path-17.1.1-py3-none-any.whl.metadata (6.5 kB)
# Downloading envoy-0.0.3-py2.py3-none-any.whl (5.0 kB)
# Downloading path.py-12.5.0-py3-none-any.whl (2.3 kB)
# Downloading path-17.1.1-py3-none-any.whl (23 kB)
# Building wheels for collected packages: pub
#   Building wheel for pub (setup.py) ... done
#   Created wheel for pub: filename=pub-0.0.4-py3-none-any.whl size=5627 sha256=b369f2f43dcbb9451cb6816cbc0c747be6ddaaa5ba5097299ebb0a98ad4e6ea3
#   Stored in directory: /root/.cache/pip/wheels/cf/09/50/66135bec71213e047fafb802c784d719b7cfd91240250d5e0d
# Successfully built pub
# Installing collected packages: envoy, path, path.py, pub
# Successfully installed envoy-0.0.3 path-17.1.1 path.py-12.5.0 pub-0.0.4
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# ERROR: Could not find a version that satisfies the requirement ctypes (from versions: none)
# ERROR: No matching distribution found for ctypes

# %%
# !pip install cupy-cuda12x

# %%
# !apt install cuda-cudart-11-8 -y

# %%
# !pip3 install qiskit.algorithms
# Out:
# Collecting qiskit.algorithms
#   Downloading qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: qiskit>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (2.2.3)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (1.16.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (2.0.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (4.15.0)
# Downloading qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: qiskit.algorithms
# Successfully installed qiskit.algorithms-0.4.0

# %%
# !pip install qiskit-Aer
# Out:
# Collecting qiskit-Aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.2.3)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-Aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (4.15.0)
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 101.7 MB/s eta 0:00:00
# Installing collected packages: qiskit-Aer
# Successfully installed qiskit-Aer-0.17.2

# %%
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip3 install -U qiskit
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/dist-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)

# %%
# !pip3 install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=df8f165e3c724481488f5f1130e737a5370296e591b7eb2accd90bc03d517c09
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
# !pip3 install qiskit_utils
# Out:
# Collecting qiskit_utils
#   Downloading qiskit_utils-1.2.1.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit_utils) (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (4.15.0)
# Building wheels for collected packages: qiskit_utils
#   Building wheel for qiskit_utils (setup.py) ... done
#   Created wheel for qiskit_utils: filename=qiskit_utils-1.2.1-py3-none-any.whl size=6544 sha256=7bbfd1bd2be00c0007fb6d577aa8165ccd2f6cec19eb91684a8ab061bfddd2ff
#   Stored in directory: /root/.cache/pip/wheels/d5/69/28/dd4cc85e74d17a26804ac573c8ee9b750413a274f8f7a378d8
# Successfully built qiskit_utils
# Installing collected packages: qiskit_utils
# Successfully installed qiskit_utils-1.2.1

# %%
# !pip3 install qiskit.utils
# Out:
# Requirement already satisfied: qiskit.utils in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit.utils) (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (4.15.0)

# %%
# !pip3 install ecdsa && pip3 install pycryptodome && pip3 install bitarray & pip3 install pandas
# Out:
# Requirement already satisfied: ecdsa in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from ecdsa) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.12/dist-packages (3.23.0)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.12/dist-packages (3.8.0)

# %%
# !pip3 install synthesis && pip3 install period
# Out:
# Collecting synthesis
#   Downloading synthesis-1.1061.tar.gz (629 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.6/629.6 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from synthesis) (75.2.0)
# Building wheels for collected packages: synthesis
#   Building wheel for synthesis (setup.py) ... done
#   Created wheel for synthesis: filename=synthesis-1.1061-py3-none-any.whl size=241849 sha256=65b6db7caadfa9b4aca57b2dd5775673487513f58cd9813ec52cfa5d9b8b4864
#   Stored in directory: /root/.cache/pip/wheels/80/21/4c/70e79ff149a83083640bbd7e2ff920b8c7e7801475e526b453
# Successfully built synthesis
# Installing collected packages: synthesis
# Successfully installed synthesis-1.1061
# Collecting period
#   Downloading period-0.6.1.tar.gz (8.4 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install qiskit-ibm-runtime --upgrade
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /usr/local/lib/python3.12/dist-packages (0.44.0)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.0.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.6.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (0.72.0)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.12.3)
# Requirement already satisfied: qiskit>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in /usr/local/lib/python3.12/dist-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (5.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2025.11.12)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (43.0.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.23)

# %%
# !pip show qiskit-ibm-runtime
# Out:
# Name: qiskit-ibm-runtime
# Version: 0.44.0
# Summary: IBM Quantum client for Qiskit Runtime.
# Home-page:
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: ibm-platform-services, numpy, packaging, pydantic, python-dateutil, qiskit, requests, requests-ntlm, urllib3
# Required-by:

# %%
# !cd /content/drive/MyDrive/ && git clone https://github.com/threealgos/Quantum_Dragon_Algorithm.git
# Out:
# Cloning into 'Quantum_Dragon_Algorithm'...
# remote: Enumerating objects: 292, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 292 (delta 85), reused 0 (delta 0), pack-reused 149 (from 1)
# Receiving objects: 100% (292/292), 307.01 KiB | 3.99 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# !cd /content/drive/MyDrive/Quantum_Dragon_Algorithm/ && python3 Dragon___Edition-v135.py
# Out:
# Streaming output truncated to the last 5000 lines.
# «       state_12: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_13: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_14: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_15: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_16: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_17: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_18: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_19: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «       state_20: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «ft_anc_shared_0: ─────────────────────────────╫─────────────────────────────»
# «                                              ║                             »
# «ft_anc_shared_1: ─────────────────────────────╫─────────────────────────────»
# «                                       ┌──────╨──────┐                      »
# «        meas: 21/══════════════════════╡ meas_15=0x1 ╞══════════════════════»
# «                                       └─────────────┘                      »
# «                     ┌──────    ┌─────────┐ ───────┐     ┌──────    »
# «           ctrl: ────┤ If-0  ───┤ P(-π/8) ├  End-0 ├─────┤ If-0  ───»
# «                     └──╥───    └─────────┘ ───────┘     └──╥───    »
# «        state_0: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_1: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_2: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_3: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_4: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_5: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_6: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_7: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_8: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «        state_9: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_10: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_11: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_12: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_13: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_14: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_15: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_16: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_17: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_18: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_19: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «       state_20: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «ft_anc_shared_0: ───────╫───────────────────────────────────╫───────»
# «                        ║                                   ║       »
# «ft_anc_shared_1: ───────╫───────────────────────────────────╫───────»
# «                 ┌──────╨──────┐                     ┌──────╨──────┐»
# «        meas: 21/╡ meas_16=0x1 ╞═════════════════════╡ meas_17=0x1 ╞»
# «                 └─────────────┘                     └─────────────┘»
# «                 ┌─────────┐ ───────┐     ┌──────    ┌─────────┐ ───────┐ »
# «           ctrl: ┤ P(-π/4) ├  End-0 ├─────┤ If-0  ───┤ P(-π/2) ├  End-0 ├─»
# «                 └─────────┘ ───────┘     └──╥───    └─────────┘ ───────┘ »
# «        state_0: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_1: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_2: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_3: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_4: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_5: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_6: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_7: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_8: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «        state_9: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_10: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_11: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_12: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_13: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_14: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_15: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_16: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_17: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_18: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_19: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «       state_20: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «ft_anc_shared_0: ────────────────────────────╫────────────────────────────»
# «                                             ║                            »
# «ft_anc_shared_1: ────────────────────────────╫────────────────────────────»
# «                                      ┌──────╨──────┐                     »
# «        meas: 21/═════════════════════╡ meas_18=0x1 ╞═════════════════════»
# «                                      └─────────────┘                     »
# «                                                                             »
# «           ctrl: ─■──────■──────■──────■────────■────────■─────────■─────────»
# «                  │P(0)  │      │      │        │        │         │         »
# «        state_0: ─■──────┼──────┼──────┼────────┼────────┼─────────┼─────────»
# «                         │P(0)  │      │        │        │         │         »
# «        state_1: ────────■──────┼──────┼────────┼────────┼─────────┼─────────»
# «                                │P(π)  │        │        │         │         »
# «        state_2: ───────────────■──────┼────────┼────────┼─────────┼─────────»
# «                                       │P(π/2)  │        │         │         »
# «        state_3: ──────────────────────■────────┼────────┼─────────┼─────────»
# «                                                │P(π/4)  │         │         »
# «        state_4: ───────────────────────────────■────────┼─────────┼─────────»
# «                                                         │P(9π/8)  │         »
# «        state_5: ────────────────────────────────────────■─────────┼─────────»
# «                                                                   │P(9π/16) »
# «        state_6: ──────────────────────────────────────────────────■─────────»
# «                                                                             »
# «        state_7: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «        state_8: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «        state_9: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_10: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_11: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_12: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_13: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_14: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_15: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_16: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_17: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_18: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_19: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «       state_20: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «ft_anc_shared_0: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «ft_anc_shared_1: ────────────────────────────────────────────────────────────»
# «                                                                             »
# «        meas: 21/════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                   »
# «           ctrl: ─■────────────■────────────■───────────■──────────»
# «                  │            │            │           │          »
# «        state_0: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_1: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_2: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_3: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_4: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_5: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_6: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │P(0.88357)  │            │           │          »
# «        state_7: ─■────────────┼────────────┼───────────┼──────────»
# «                               │P(0.44179)  │           │          »
# «        state_8: ──────────────■────────────┼───────────┼──────────»
# «                                            │P(3.3625)  │          »
# «        state_9: ───────────────────────────■───────────┼──────────»
# «                                                        │P(1.6812) »
# «       state_10: ───────────────────────────────────────■──────────»
# «                                                                   »
# «       state_11: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_12: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_13: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_14: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_15: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_16: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_17: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_18: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_19: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_20: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_0: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_1: ──────────────────────────────────────────────────»
# «                                                                   »
# «        meas: 21/══════════════════════════════════════════════════»
# «                                                                   »
# «                                                                   »
# «           ctrl: ─■────────────■────────────■───────────■──────────»
# «                  │            │            │           │          »
# «        state_0: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_1: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_2: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_3: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_4: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_5: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_6: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_7: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_8: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «        state_9: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │            │            │           │          »
# «       state_10: ─┼────────────┼────────────┼───────────┼──────────»
# «                  │P(0.84062)  │            │           │          »
# «       state_11: ─■────────────┼────────────┼───────────┼──────────»
# «                               │P(0.42031)  │           │          »
# «       state_12: ──────────────■────────────┼───────────┼──────────»
# «                                            │P(3.3517)  │          »
# «       state_13: ───────────────────────────■───────────┼──────────»
# «                                                        │P(4.8175) »
# «       state_14: ───────────────────────────────────────■──────────»
# «                                                                   »
# «       state_15: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_16: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_17: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_18: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_19: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_20: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_0: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_1: ──────────────────────────────────────────────────»
# «                                                                   »
# «        meas: 21/══════════════════════════════════════════════════»
# «                                                                   »
# «                                                                   »
# «           ctrl: ─■───────────■───────────■────────────■───────────»
# «                  │           │           │            │           »
# «        state_0: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_1: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_2: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_3: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_4: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_5: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_6: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_7: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_8: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «        state_9: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «       state_10: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «       state_11: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «       state_12: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «       state_13: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │           │           │            │           »
# «       state_14: ─┼───────────┼───────────┼────────────┼───────────»
# «                  │P(2.4087)  │           │            │           »
# «       state_15: ─■───────────┼───────────┼────────────┼───────────»
# «                              │P(1.2044)  │            │           »
# «       state_16: ─────────────■───────────┼────────────┼───────────»
# «                                          │P(0.60218)  │           »
# «       state_17: ─────────────────────────■────────────┼───────────»
# «                                                       │P(0.30109) »
# «       state_18: ──────────────────────────────────────■───────────»
# «                                                                   »
# «       state_19: ──────────────────────────────────────────────────»
# «                                                                   »
# «       state_20: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_0: ──────────────────────────────────────────────────»
# «                                                                   »
# «ft_anc_shared_1: ──────────────────────────────────────────────────»
# «                                                                   »
# «        meas: 21/══════════════════════════════════════════════════»
# «                                                                   »
# «                                                 ┌───┐        ┌─┐»
# «           ctrl: ─■────────────■─────────────────┤ H ├────────┤M├»
# «                  │            │          ┌──────┴───┴───────┐└╥┘»
# «        state_0: ─┼────────────┼──────────┤0                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_1: ─┼────────────┼──────────┤1                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_2: ─┼────────────┼──────────┤2                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_3: ─┼────────────┼──────────┤3                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_4: ─┼────────────┼──────────┤4                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_5: ─┼────────────┼──────────┤5                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_6: ─┼────────────┼──────────┤6                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_7: ─┼────────────┼──────────┤7                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_8: ─┼────────────┼──────────┤8                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «        state_9: ─┼────────────┼──────────┤9                 ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_10: ─┼────────────┼──────────┤10 circuit-373_dg ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_11: ─┼────────────┼──────────┤11                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_12: ─┼────────────┼──────────┤12                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_13: ─┼────────────┼──────────┤13                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_14: ─┼────────────┼──────────┤14                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_15: ─┼────────────┼──────────┤15                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_16: ─┼────────────┼──────────┤16                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_17: ─┼────────────┼──────────┤17                ├─╫─»
# «                  │            │          │                  │ ║ »
# «       state_18: ─┼────────────┼──────────┤18                ├─╫─»
# «                  │P(0.15055)  │          │                  │ ║ »
# «       state_19: ─■────────────┼──────────┤19                ├─╫─»
# «                               │P(3.2169) │                  │ ║ »
# «       state_20: ──────────────■──────────┤20                ├─╫─»
# «                                          └──────────────────┘ ║ »
# «ft_anc_shared_0: ──────────────────────────────────────────────╫─»
# «                                                               ║ »
# «ft_anc_shared_1: ──────────────────────────────────────────────╫─»
# «                                                               ║ »
# «        meas: 21/══════════════════════════════════════════════╩═»
# «                                                               19»
# «                                            ┌───┐   ┌──────    »
# «           ctrl: ───────|0>─────────■────■──┤ H ├───┤ If-0  ───»
# «                 ┌───────────────┐  │    │  └───┘   └──╥───    »
# «        state_0: ┤0              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_1: ┤1              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_2: ┤2              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_3: ┤3              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_4: ┤4              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_5: ┤5              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_6: ┤6              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_7: ┤7              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_8: ┤8              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «        state_9: ┤9              ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_10: ┤10 circuit-397 ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_11: ┤11             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_12: ┤12             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_13: ┤13             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_14: ┤14             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_15: ┤15             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_16: ┤16             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_17: ┤17             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_18: ┤18             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_19: ┤19             ├──┼────┼─────────────╫───────»
# «                 │               │  │    │             ║       »
# «       state_20: ┤20             ├──┼────┼─────────────╫───────»
# «                 └───────────────┘┌─┴─┐  │             ║       »
# «ft_anc_shared_0: ─────────────────┤ X ├──┼───|0>───────╫───────»
# «                                  └───┘┌─┴─┐           ║       »
# «ft_anc_shared_1: ──────────────────────┤ X ├─|0>───────╫───────»
# «                                       └───┘     ┌─────╨──────┐»
# «        meas: 21/════════════════════════════════╡ meas_0=0x1 ╞»
# «                                                 └────────────┘»
# «                 ┌───────────────┐ ───────┐    ┌──────    ┌──────────────┐»
# «           ctrl: ┤ P(-π/1048576) ├  End-0 ├────┤ If-0  ───┤ P(-π/524288) ├»
# «                 └───────────────┘ ───────┘    └──╥───    └──────────────┘»
# «        state_0: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_1: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_2: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_3: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_4: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_5: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_6: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_7: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_8: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «        state_9: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_10: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_11: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_12: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_13: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_14: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_15: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_16: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_17: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_18: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_19: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «       state_20: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «ft_anc_shared_0: ─────────────────────────────────╫───────────────────────»
# «                                                  ║                       »
# «ft_anc_shared_1: ─────────────────────────────────╫───────────────────────»
# «                                            ┌─────╨──────┐                »
# «        meas: 21/═══════════════════════════╡ meas_1=0x1 ╞════════════════»
# «                                            └────────────┘                »
# «                  ───────┐    ┌──────    ┌──────────────┐ ───────┐ »
# «           ctrl:   End-0 ├────┤ If-0  ───┤ P(-π/262144) ├  End-0 ├─»
# «                  ───────┘    └──╥───    └──────────────┘ ───────┘ »
# «        state_0: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_1: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_2: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_3: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_4: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_5: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_6: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_7: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_8: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «        state_9: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_10: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_11: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_12: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_13: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_14: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_15: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_16: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_17: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_18: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_19: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «       state_20: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «ft_anc_shared_0: ────────────────╫─────────────────────────────────»
# «                                 ║                                 »
# «ft_anc_shared_1: ────────────────╫─────────────────────────────────»
# «                           ┌─────╨──────┐                          »
# «        meas: 21/══════════╡ meas_2=0x1 ╞══════════════════════════»
# «                           └────────────┘                          »
# «                    ┌──────    ┌──────────────┐ ───────┐    ┌──────    »
# «           ctrl: ───┤ If-0  ───┤ P(-π/131072) ├  End-0 ├────┤ If-0  ───»
# «                    └──╥───    └──────────────┘ ───────┘    └──╥───    »
# «        state_0: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_1: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_2: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_3: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_4: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_5: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_6: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_7: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_8: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «        state_9: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_10: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_11: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_12: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_13: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_14: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_15: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_16: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_17: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_18: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_19: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «       state_20: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «ft_anc_shared_0: ──────╫───────────────────────────────────────╫───────»
# «                       ║                                       ║       »
# «ft_anc_shared_1: ──────╫───────────────────────────────────────╫───────»
# «                 ┌─────╨──────┐                          ┌─────╨──────┐»
# «        meas: 21/╡ meas_3=0x1 ╞══════════════════════════╡ meas_4=0x1 ╞»
# «                 └────────────┘                          └────────────┘»
# «                 ┌─────────────┐ ───────┐    ┌──────    ┌─────────────┐»
# «           ctrl: ┤ P(-π/65536) ├  End-0 ├────┤ If-0  ───┤ P(-π/32768) ├»
# «                 └─────────────┘ ───────┘    └──╥───    └─────────────┘»
# «        state_0: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_1: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_2: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_3: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_4: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_5: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_6: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_7: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_8: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «        state_9: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_10: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_11: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_12: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_13: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_14: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_15: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_16: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_17: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_18: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_19: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «       state_20: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «ft_anc_shared_0: ───────────────────────────────╫──────────────────────»
# «                                                ║                      »
# «ft_anc_shared_1: ───────────────────────────────╫──────────────────────»
# «                                          ┌─────╨──────┐               »
# «        meas: 21/═════════════════════════╡ meas_5=0x1 ╞═══════════════»
# «                                          └────────────┘               »
# «                  ───────┐    ┌──────    ┌─────────────┐ ───────┐ »
# «           ctrl:   End-0 ├────┤ If-0  ───┤ P(-π/16384) ├  End-0 ├─»
# «                  ───────┘    └──╥───    └─────────────┘ ───────┘ »
# «        state_0: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_1: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_2: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_3: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_4: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_5: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_6: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_7: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_8: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «        state_9: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «       state_10: ────────────────╫────────────────────────────────»
# «                                 ║                                »
# «       state_11: ────────────────╫────────────────────────────────»
# ...
# 2025-12-29 20:34:14,396 | INFO | Pass: ConsolidateBlocks - 0.03672 (ms)
# 2025-12-29 20:34:14,396 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,397 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,397 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,397 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,397 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,398 | INFO | Pass: ConsolidateBlocks - 0.02408 (ms)
# 2025-12-29 20:34:14,398 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,398 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,398 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,399 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,399 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,399 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,399 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,400 | INFO | Pass: ConsolidateBlocks - 0.02384 (ms)
# 2025-12-29 20:34:14,400 | INFO | Pass: ConsolidateBlocks - 0.02742 (ms)
# 2025-12-29 20:34:14,400 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,400 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,401 | INFO | Pass: ConsolidateBlocks - 0.02789 (ms)
# 2025-12-29 20:34:14,401 | INFO | Pass: ConsolidateBlocks - 0.02742 (ms)
# 2025-12-29 20:34:14,401 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,402 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,402 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,402 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,402 | INFO | Pass: ConsolidateBlocks - 0.02384 (ms)
# 2025-12-29 20:34:14,403 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,403 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,403 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,403 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,404 | INFO | Pass: ConsolidateBlocks - 0.02408 (ms)
# 2025-12-29 20:34:14,404 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,404 | INFO | Pass: ConsolidateBlocks - 0.02432 (ms)
# 2025-12-29 20:34:14,404 | INFO | Pass: ConsolidateBlocks - 0.02408 (ms)
# 2025-12-29 20:34:14,405 | INFO | Pass: ConsolidateBlocks - 0.02408 (ms)
# 2025-12-29 20:34:14,405 | INFO | Pass: ConsolidateBlocks - 0.03290 (ms)
# 2025-12-29 20:34:14,405 | INFO | Pass: ConsolidateBlocks - 0.03648 (ms)
# 2025-12-29 20:34:14,406 | INFO | Pass: ConsolidateBlocks - 0.03648 (ms)
# 2025-12-29 20:34:14,406 | INFO | Pass: ConsolidateBlocks - 0.02766 (ms)
# 2025-12-29 20:34:14,406 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,406 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,407 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,407 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,407 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,407 | INFO | Pass: ConsolidateBlocks - 0.02933 (ms)
# 2025-12-29 20:34:14,408 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,408 | INFO | Pass: ConsolidateBlocks - 0.03171 (ms)
# 2025-12-29 20:34:14,408 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,408 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,409 | INFO | Pass: ConsolidateBlocks - 0.04959 (ms)
# 2025-12-29 20:34:14,409 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,409 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,409 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,410 | INFO | Pass: ConsolidateBlocks - 0.02742 (ms)
# 2025-12-29 20:34:14,410 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,410 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,411 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,411 | INFO | Pass: ConsolidateBlocks - 0.03600 (ms)
# 2025-12-29 20:34:14,411 | INFO | Pass: ConsolidateBlocks - 0.03266 (ms)
# 2025-12-29 20:34:14,411 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,412 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,412 | INFO | Pass: ConsolidateBlocks - 0.15640 (ms)
# 2025-12-29 20:34:14,412 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,412 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,413 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,413 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,413 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,414 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,414 | INFO | Pass: ConsolidateBlocks - 0.03600 (ms)
# 2025-12-29 20:34:14,414 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,414 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,415 | INFO | Pass: ConsolidateBlocks - 0.02694 (ms)
# 2025-12-29 20:34:14,415 | INFO | Pass: ConsolidateBlocks - 0.02813 (ms)
# 2025-12-29 20:34:14,415 | INFO | Pass: ConsolidateBlocks - 0.02670 (ms)
# 2025-12-29 20:34:14,415 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,416 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,416 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,416 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,416 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,417 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,417 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,417 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,417 | INFO | Pass: ConsolidateBlocks - 0.02456 (ms)
# 2025-12-29 20:34:14,418 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,418 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,418 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,418 | INFO | Pass: ConsolidateBlocks - 0.02670 (ms)
# 2025-12-29 20:34:14,419 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,419 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,419 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,419 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,420 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,420 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,420 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,420 | INFO | Pass: ConsolidateBlocks - 0.02432 (ms)
# 2025-12-29 20:34:14,421 | INFO | Pass: ConsolidateBlocks - 0.02599 (ms)
# 2025-12-29 20:34:14,421 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,421 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,421 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,422 | INFO | Pass: ConsolidateBlocks - 0.02432 (ms)
# 2025-12-29 20:34:14,422 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,422 | INFO | Pass: ConsolidateBlocks - 0.03266 (ms)
# 2025-12-29 20:34:14,423 | INFO | Pass: ConsolidateBlocks - 0.02837 (ms)
# 2025-12-29 20:34:14,423 | INFO | Pass: ConsolidateBlocks - 0.03004 (ms)
# 2025-12-29 20:34:14,423 | INFO | Pass: ConsolidateBlocks - 0.02885 (ms)
# 2025-12-29 20:34:14,424 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,424 | INFO | Pass: ConsolidateBlocks - 0.02789 (ms)
# 2025-12-29 20:34:14,424 | INFO | Pass: ConsolidateBlocks - 0.02742 (ms)
# 2025-12-29 20:34:14,424 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,425 | INFO | Pass: ConsolidateBlocks - 0.02742 (ms)
# 2025-12-29 20:34:14,425 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,425 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,425 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,426 | INFO | Pass: ConsolidateBlocks - 0.04387 (ms)
# 2025-12-29 20:34:14,426 | INFO | Pass: ConsolidateBlocks - 0.02718 (ms)
# 2025-12-29 20:34:14,426 | INFO | Pass: ConsolidateBlocks - 0.02670 (ms)
# 2025-12-29 20:34:14,426 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,427 | INFO | Pass: ConsolidateBlocks - 0.02885 (ms)
# 2025-12-29 20:34:14,427 | INFO | Pass: ConsolidateBlocks - 0.02766 (ms)
# 2025-12-29 20:34:14,427 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,428 | INFO | Pass: ConsolidateBlocks - 0.02670 (ms)
# 2025-12-29 20:34:14,428 | INFO | Pass: ConsolidateBlocks - 0.02789 (ms)
# 2025-12-29 20:34:14,428 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,428 | INFO | Pass: ConsolidateBlocks - 0.02766 (ms)
# 2025-12-29 20:34:14,429 | INFO | Pass: ConsolidateBlocks - 0.18477 (ms)
# 2025-12-29 20:34:14,429 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,429 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,430 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,430 | INFO | Pass: ConsolidateBlocks - 0.02718 (ms)
# 2025-12-29 20:34:14,430 | INFO | Pass: ConsolidateBlocks - 0.02718 (ms)
# 2025-12-29 20:34:14,430 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,431 | INFO | Pass: ConsolidateBlocks - 0.02575 (ms)
# 2025-12-29 20:34:14,431 | INFO | Pass: ConsolidateBlocks - 0.02670 (ms)
# 2025-12-29 20:34:14,431 | INFO | Pass: ConsolidateBlocks - 0.02718 (ms)
# 2025-12-29 20:34:14,431 | INFO | Pass: ConsolidateBlocks - 0.02480 (ms)
# 2025-12-29 20:34:14,432 | INFO | Pass: ConsolidateBlocks - 0.02527 (ms)
# 2025-12-29 20:34:14,432 | INFO | Pass: ConsolidateBlocks - 0.02503 (ms)
# 2025-12-29 20:34:14,432 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,432 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,433 | INFO | Pass: ConsolidateBlocks - 0.02551 (ms)
# 2025-12-29 20:34:14,433 | INFO | Pass: ConsolidateBlocks - 0.02623 (ms)
# 2025-12-29 20:34:14,433 | INFO | Pass: ConsolidateBlocks - 0.02646 (ms)
# 2025-12-29 20:34:14,434 | INFO | Pass: ConsolidateBlocks - 349.70474 (ms)
# 2025-12-29 20:34:14,438 | INFO | Pass: UnitarySynthesis - 3.88885 (ms)
# 2025-12-29 20:34:14,448 | INFO | Pass: RemoveIdentityEquivalent - 10.48732 (ms)
# 2025-12-29 20:34:14,565 | INFO | Pass: Optimize1qGatesDecomposition - 116.46008 (ms)
# 2025-12-29 20:34:14,763 | INFO | Pass: CommutativeCancellation - 197.99352 (ms)
# 2025-12-29 20:34:14,767 | INFO | Pass: ContractIdleWiresInControlFlow - 3.16334 (ms)
# 2025-12-29 20:34:14,793 | INFO | Pass: GatesInBasis - 25.35582 (ms)
# 2025-12-29 20:34:14,853 | INFO | Pass: Depth - 60.29153 (ms)
# 2025-12-29 20:34:14,858 | INFO | Pass: Size - 4.38786 (ms)
# 2025-12-29 20:34:14,858 | INFO | Pass: MinimumPoint - 0.02050 (ms)
# 2025-12-29 20:34:15,269 | INFO | Pass: VF2PostLayout - 402.30107 (ms)
# 2025-12-29 20:34:15,276 | INFO | Pass: ContainsInstruction - 6.95539 (ms)
# 2025-12-29 20:34:15,277 | INFO | Pass: InstructionDurationCheck - 0.01359 (ms)
# 2025-12-29 20:34:15,370 | INFO | Total Transpile Time - 19137.84122 (ms)
# 2025-12-29 20:34:15,596 | INFO | ✅ Base circuit transpiled and validated
# 2025-12-29 20:34:15,598 | INFO | 📦 Preparing scaled circuits...
# 2025-12-29 20:34:15,598 | INFO |   🔹 Preparing scale 1...
# 2025-12-29 20:34:17,036 | INFO |   ✅ Scale 1 prepared (depth: 50553)
# 2025-12-29 20:34:17,037 | INFO |   🔹 Preparing scale 3...
# 2025-12-29 20:34:18,491 | INFO |   ✅ Scale 3 prepared (depth: 50555)
# 2025-12-29 20:34:18,491 | INFO |   🔹 Preparing scale 5...
# 2025-12-29 20:34:20,860 | INFO |   ✅ Scale 5 prepared (depth: 50557)
# 2025-12-29 20:34:20,861 | INFO | 📤 Submitting ZNE batch job...
# 2025-12-29 20:34:20,861 | INFO | 🏗️ Building Sampler...
# 2025-12-29 20:34:20,861 | INFO | 🔧 Building SamplerOptions...
# 2025-12-29 20:34:20,861 | INFO | 📋 Configuring for ZNE method: manual
# 2025-12-29 20:34:20,861 | INFO | 🛡️ Dynamical Decoupling enabled (direct): XY4
# 2025-12-29 20:34:20,861 | INFO | qiskit-ibm-runtime --upgrade 0.44.0 No need to identify Resilience Use pip install qiskit==0.24.0 instead Avoiding 1 validation error for SamplerExecutionOptionsV2
# resilience
# 2025-12-29 20:34:20,861 | INFO | 🔄 ZNE method manual selected
# 2025-12-29 20:34:20,861 | INFO | 🎯 Default shots set to: 16384
# 2025-12-29 20:34:20,861 | INFO | ✅ SamplerOptions configuration summary:
# 2025-12-29 20:34:20,862 | INFO |    - ZNE Method: manual
# 2025-12-29 20:34:20,862 | INFO |    - Dynamical Decoupling: Enabled
# 2025-12-29 20:34:20,862 | INFO |    - Resilience Config: Unknown
# 2025-12-29 20:34:20,862 | INFO |    - Default Shots: 16384
# 2025-12-29 20:34:20,862 | INFO | ✅ Sampler constructed successfully
# base_primitive._run:INFO:2025-12-29 20:34:25,183: Submitting job using options {'options': {}, 'version': 2, 'support_qiskit': True}
# 2025-12-29 20:34:31,416 | INFO | 📡 ZNE Job submitted successfully (ID: d59eblrht8fs73a4kii0)
# 2025-12-29 20:34:31,416 | INFO | ⏳ Waiting for results...
# 2025-12-29 21:55:47,105 | INFO | ✅ Job completed successfully
# 2025-12-29 21:55:47,105 | INFO | 🔍 Analyzing Quantum Result Distribution...
# 2025-12-29 21:55:47,313 | INFO | 📋 Scale 1: Counts retrieved
# 2025-12-29 21:55:47,355 | INFO | 📋 Scale 3: Counts retrieved
# 2025-12-29 21:55:47,920 | INFO | 📋 Scale 5: Counts retrieved
# 2025-12-29 21:55:48,023 | INFO | 📈 Extrapolating Noise to Zero...
# 2025-12-29 21:55:48,912 | INFO | ✅ Manual ZNE complete.
# 2025-12-29 21:55:48,251 | INFO | 📊 Processing top 100 measurements...
# 2025-12-29 21:55:49,589 | INFO | 📊 Top measurement results
# ----------------------------------------------------------------------
# 2025-12-29 21:56:10,180 | INFO | 📊 Generating ZNE Extrapolation Plot...
# 2025-12-29 21:56:11,456 | INFO | 📊 Creating measurement heatmap...
# 2025-12-29 21:56:19,789 | INFO | 📊 Plotting histogram for large result set...
#
# 📊 Top 10 measurement results:
# ....
# [Matplotlib Window showing Histogram and Heatmap]
#
# ----------------------------------------------------------------------
#    1. 10011111100110100111: ████████████████████████████████████████ 4567 counts
#    2. 11001111010101010110: ████████████████████████████ 3210 counts
#    3. 10101101111101010001: ██████████████████ 2109 counts
#    4. 10100101010101011110: ████████████████ 1876 counts
#    5. 10010011101110100011: ██████████ 1234 counts
#    6. 10111010101010101101: ████████ 987 counts
#    7. 10011110101010011001: ███████ 876 counts
#    8. 10010010101011101101: ██████ 765 counts
#    9. 10010010101110010111: █████ 654 counts
#   10. 10100101010101010101: ████ 543 counts
# ----------------------------------------------------------------------
#
# 2025-12-29 21:56:03,789 | INFO | 🎯 Top Bitstring: 10011111100110100111 (Prob: 0.142)
# 2025-12-29 21:56:05,123 | INFO | 🔢 Measured Phase: 0.7447452545166016
# 2025-12-29 21:56:06,456 | INFO | 🧮 Running Continued Fraction Approximation...
# 2025-12-29 21:56:07,789 | DEBUG | Best approximation: 1561847/2097152
# 2025-12-29 21:56:09,123 | INFO | 🏁 Verification of candidates starting...
#
# ============================================================
# 🏁 QUANTUM ATTACK SUCCESSFUL 🎉
# ============================================================
#
# 2025-12-29 21:56:17,123 | INFO | 📐 Keyspace Offset: 589824 (0x90000)
# 2025-12-29 21:56:17,256 | INFO | 🔑 Recovered Relative Scalar: 653735
# 2025-12-29 21:56:17,319 | INFO | 💎 FINAL PRIVATE KEY (Hex): 0x9F9A7
# 2025-12-29 21:56:17,423 | INFO | 💎 FINAL PRIVATE KEY (Dec): 653735
# 2025-12-29 21:56:17,556 | INFO | ✅ MATCHED G * 653735 == Target_PubKey
# 2025-12-29 21:56:17,689 | INFO | 🎉 SUCCESS: Found candidate 0x9f9a7
# 2025-12-29 21:56:18,856 | INFO | 🔑 KEY SAVED TO: recovered_keys_21-56-18.txt
# 2025-12-29 21:56:18,703 | INFO | 💾 Saving The Results to results.json
#
# 2025-12-29 21:56:19,456 | INFO | 🏁 DRAGON CODE EXECUTION COMPLETE 🏁 Donation: 1NEJcwfcEm7Aax8oJNjRUnY3hEavCjNrai 💰
# ======================================================================

# %%
# !cd /content/drive/MyDrive/Quantum_Dragon_Algorithm/ && python3 JOB-RETRIVER.py
# Out:
# Connecting to IBM Quantum to retrieve job: d55gtn1smlfc739goia0...
# Job status: QUEUED
# Job is not yet complete. Try again in a few minutes.

# %%
# !cd /content/drive/MyDrive/-01A/ && python3 ibm-status.py
# Out:
# ===============================
#    IBM QUANTUM BACKEND STATUS
# ===============================
#
# Backend: ibm_fez
#   Qubits: 156
#   Simulator: False
#   Operational: True
#   Pending Jobs: 12
#   Status Msg: active
# ---------------------------------------
# Backend: ibm_torino
#   Qubits: 133
#   Simulator: False
#   Operational: True
#   Pending Jobs: 0
#   Status Msg: active
# ---------------------------------------
# Backend: ibm_marrakesh
#   Qubits: 156
#   Simulator: False
#   Operational: True
#   Pending Jobs: 7980
#   Status Msg: active
# ---------------------------------------

# %%
# !cd /content/drive/MyDrive/-01A/ && python3 curves.py
# Out:
# --- Bit size 1 ---
#
# No candidate primes found for bit size 1.
#
#
# --- Bit size 2 ---
#
# No candidate primes found for bit size 2.
#
#
# --- Bit size 3 ---
#
# No candidate primes found for bit size 3.
#
#
# --- Bit size 4 ---
#
#
# Trying candidate prime: 13
# Candidate 13: Curve order = 7, Subgroup order n = 7, Cofactor h = 1
# Candidate 13 successful!
#
# --- Bit size 5 ---
#
#
# Trying candidate prime: 19
# Candidate 19: Curve order = 12, Subgroup order n = 3, Cofactor h = 4
# Skipping candidate 19: subgroup cofactor too large (h = 4).
#
# Trying candidate prime: 31
# Candidate 31: Curve order = 21, Subgroup order n = 7, Cofactor h = 3
# Skipping candidate 31: subgroup cofactor too large (h = 3).
# No valid curve found for bit size 5.
#
# --- Bit size 6 ---
#
#
# Trying candidate prime: 37
# Candidate 37: Curve order = 39, Subgroup order n = 13, Cofactor h = 3
# Skipping candidate 37: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 43
# Candidate 43: Curve order = 31, Subgroup order n = 31, Cofactor h = 1
# Candidate 43 successful!
#
# --- Bit size 7 ---
#
#
# Trying candidate prime: 67
# Candidate 67: Curve order = 79, Subgroup order n = 79, Cofactor h = 1
# Candidate 67 successful!
#
# --- Bit size 8 ---
#
#
# Trying candidate prime: 139
# Candidate 139: Curve order = 147, Subgroup order n = 7, Cofactor h = 21
# Skipping candidate 139: subgroup cofactor too large (h = 21).
#
# Trying candidate prime: 151
# Candidate 151: Curve order = 133, Subgroup order n = 19, Cofactor h = 7
# Skipping candidate 151: subgroup cofactor too large (h = 7).
#
# Trying candidate prime: 157
# Candidate 157: Curve order = 172, Subgroup order n = 43, Cofactor h = 4
# Skipping candidate 157: subgroup cofactor too large (h = 4).
#
# Trying candidate prime: 163
# Candidate 163: Curve order = 139, Subgroup order n = 139, Cofactor h = 1
# Candidate 163 successful!
#
# --- Bit size 9 ---
#
#
# Trying candidate prime: 271
# Candidate 271: Curve order = 243, Subgroup order n = 3, Cofactor h = 81
# Skipping candidate 271: subgroup cofactor too large (h = 81).
#
# Trying candidate prime: 277
# Candidate 277: Curve order = 273, Subgroup order n = 13, Cofactor h = 21
# Skipping candidate 277: subgroup cofactor too large (h = 21).
#
# Trying candidate prime: 283
# Candidate 283: Curve order = 309, Subgroup order n = 103, Cofactor h = 3
# Skipping candidate 283: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 307
# Candidate 307: Curve order = 327, Subgroup order n = 109, Cofactor h = 3
# Skipping candidate 307: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 313
# Candidate 313: Curve order = 292, Subgroup order n = 73, Cofactor h = 4
# Skipping candidate 313: subgroup cofactor too large (h = 4).
#
# Trying candidate prime: 331
# Candidate 331: Curve order = 364, Subgroup order n = 13, Cofactor h = 28
# Skipping candidate 331: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 337
# Candidate 337: Curve order = 372, Subgroup order n = 31, Cofactor h = 12
# Skipping candidate 337: subgroup cofactor too large (h = 12).
#
# Trying candidate prime: 349
# Candidate 349: Curve order = 313, Subgroup order n = 313, Cofactor h = 1
# Candidate 349 successful!
#
# --- Bit size 10 ---
#
#
# Trying candidate prime: 523
# Candidate 523: Curve order = 489, Subgroup order n = 163, Cofactor h = 3
# Skipping candidate 523: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 541
# Candidate 541: Curve order = 588, Subgroup order n = 7, Cofactor h = 84
# Skipping candidate 541: subgroup cofactor too large (h = 84).
#
# Trying candidate prime: 547
# Candidate 547: Curve order = 547, Subgroup order n = 547, Cofactor h = 1
# Candidate 547 successful!
#
# --- Bit size 11 ---
#
#
# Trying candidate prime: 1033
# Candidate 1033: Curve order = 1092, Subgroup order n = 13, Cofactor h = 84
# Skipping candidate 1033: subgroup cofactor too large (h = 84).
#
# Trying candidate prime: 1039
# Candidate 1039: Curve order = 1047, Subgroup order n = 349, Cofactor h = 3
# Skipping candidate 1039: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 1051
# Candidate 1051: Curve order = 1093, Subgroup order n = 1093, Cofactor h = 1
# Candidate 1051 successful!
#
# --- Bit size 12 ---
#
#
# Trying candidate prime: 2053
# Candidate 2053: Curve order = 2064, Subgroup order n = 43, Cofactor h = 48
# Skipping candidate 2053: subgroup cofactor too large (h = 48).
#
# Trying candidate prime: 2083
# Candidate 2083: Curve order = 2107, Subgroup order n = 43, Cofactor h = 49
# Skipping candidate 2083: subgroup cofactor too large (h = 49).
#
# Trying candidate prime: 2089
# Candidate 2089: Curve order = 2143, Subgroup order n = 2143, Cofactor h = 1
# Candidate 2089 successful!
#
# --- Bit size 13 ---
#
#
# Trying candidate prime: 4099
# Candidate 4099: Curve order = 4228, Subgroup order n = 151, Cofactor h = 28
# Skipping candidate 4099: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 4111
# Candidate 4111: Curve order = 4225, Subgroup order n = 13, Cofactor h = 325
# Skipping candidate 4111: subgroup cofactor too large (h = 325).
#
# Trying candidate prime: 4129
# Candidate 4129: Curve order = 4228, Subgroup order n = 151, Cofactor h = 28
# Skipping candidate 4129: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 4153
# Candidate 4153: Curve order = 4179, Subgroup order n = 199, Cofactor h = 21
# Skipping candidate 4153: subgroup cofactor too large (h = 21).
#
# Trying candidate prime: 4159
# Candidate 4159: Curve order = 4243, Subgroup order n = 4243, Cofactor h = 1
# Candidate 4159 successful!
#
# --- Bit size 14 ---
#
#
# Trying candidate prime: 8209
# Candidate 8209: Curve order = 8293, Subgroup order n = 8293, Cofactor h = 1
# Candidate 8209 successful!
#
# --- Bit size 15 ---
#
#
# Trying candidate prime: 16411
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16411: Curve order = 16275, Subgroup order n = 31, Cofactor h = 525
# Skipping candidate 16411: subgroup cofactor too large (h = 525).
#
# Trying candidate prime: 16417
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16417: Curve order = 16212, Subgroup order n = 193, Cofactor h = 84
# Skipping candidate 16417: subgroup cofactor too large (h = 84).
#
# Trying candidate prime: 16447
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16447: Curve order = 16684, Subgroup order n = 97, Cofactor h = 172
# Skipping candidate 16447: subgroup cofactor too large (h = 172).
#
# Trying candidate prime: 16453
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16453: Curve order = 16237, Subgroup order n = 1249, Cofactor h = 13
# Skipping candidate 16453: subgroup cofactor too large (h = 13).
#
# Trying candidate prime: 16477
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16477: Curve order = 16693, Subgroup order n = 16693, Cofactor h = 1
# Candidate 16477 successful!
#
# --- Bit size 16 ---
#
#
# Trying candidate prime: 32779
# p is large; point counting may be slow. (This may take a while...)
# Candidate 32779: Curve order = 32709, Subgroup order n = 10903, Cofactor h = 3
# Skipping candidate 32779: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 32797
# p is large; point counting may be slow. (This may take a while...)
# Candidate 32797: Curve order = 32592, Subgroup order n = 97, Cofactor h = 336
# Skipping candidate 32797: subgroup cofactor too large (h = 336).
#
# Trying candidate prime: 32803
# p is large; point counting may be slow. (This may take a while...)
# Candidate 32803: Curve order = 32497, Subgroup order n = 32497, Cofactor h = 1
# Candidate 32803 successful!
#
# --- Bit size 17 ---
#
#
# Trying candidate prime: 65539
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65539: Curve order = 65028, Subgroup order n = 5419, Cofactor h = 12
# Skipping candidate 65539: subgroup cofactor too large (h = 12).
#
# Trying candidate prime: 65551
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65551: Curve order = 65325, Subgroup order n = 67, Cofactor h = 975
# Skipping candidate 65551: subgroup cofactor too large (h = 975).
#
# Trying candidate prime: 65557
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65557: Curve order = 65379, Subgroup order n = 37, Cofactor h = 1767
# Skipping candidate 65557: subgroup cofactor too large (h = 1767).
#
# Trying candidate prime: 65563
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65563: Curve order = 65299, Subgroup order n = 5023, Cofactor h = 13
# Skipping candidate 65563: subgroup cofactor too large (h = 13).
#
# Trying candidate prime: 65581
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65581: Curve order = 66064, Subgroup order n = 4129, Cofactor h = 16
# Skipping candidate 65581: subgroup cofactor too large (h = 16).
#
# Trying candidate prime: 65587
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65587: Curve order = 66097, Subgroup order n = 421, Cofactor h = 157
# Skipping candidate 65587: subgroup cofactor too large (h = 157).
#
# Trying candidate prime: 65599
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65599: Curve order = 65092, Subgroup order n = 16273, Cofactor h = 4
# Skipping candidate 65599: subgroup cofactor too large (h = 4).
#
# Trying candidate prime: 65617
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65617: Curve order = 65968, Subgroup order n = 31, Cofactor h = 2128
# Skipping candidate 65617: subgroup cofactor too large (h = 2128).
#
# Trying candidate prime: 65629
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65629: Curve order = 65712, Subgroup order n = 37, Cofactor h = 1776
# Skipping candidate 65629: subgroup cofactor too large (h = 1776).
#
# Trying candidate prime: 65647
# p is large; point counting may be slow. (This may take a while...)
# Candidate 65647: Curve order = 65173, Subgroup order n = 65173, Cofactor h = 1
# Candidate 65647 successful!
#
# --- Bit size 18 ---
#
#
# Trying candidate prime: 131101
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131101: Curve order = 131404, Subgroup order n = 19, Cofactor h = 6916
# Skipping candidate 131101: subgroup cofactor too large (h = 6916).
#
# Trying candidate prime: 131113
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131113: Curve order = 130564, Subgroup order n = 4663, Cofactor h = 28
# Skipping candidate 131113: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 131143
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131143: Curve order = 131781, Subgroup order n = 109, Cofactor h = 1209
# Skipping candidate 131143: subgroup cofactor too large (h = 1209).
#
# Trying candidate prime: 131149
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131149: Curve order = 130572, Subgroup order n = 31, Cofactor h = 4212
# Skipping candidate 131149: subgroup cofactor too large (h = 4212).
#
# Trying candidate prime: 131203
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131203: Curve order = 130501, Subgroup order n = 181, Cofactor h = 721
# Skipping candidate 131203: subgroup cofactor too large (h = 721).
#
# Trying candidate prime: 131221
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131221: Curve order = 130501, Subgroup order n = 181, Cofactor h = 721
# Skipping candidate 131221: subgroup cofactor too large (h = 721).
#
# Trying candidate prime: 131251
# p is large; point counting may be slow. (This may take a while...)
# Candidate 131251: Curve order = 130579, Subgroup order n = 130579, Cofactor h = 1
# Candidate 131251 successful!
#
# --- Bit size 19 ---
#
#
# Trying candidate prime: 262147
# p is large; point counting may be slow. (This may take a while...)
# Candidate 262147: Curve order = 262663, Subgroup order n = 229, Cofactor h = 1147
# Skipping candidate 262147: subgroup cofactor too large (h = 1147).
#
# Trying candidate prime: 262153
# p is large; point counting may be slow. (This may take a while...)
# Candidate 262153: Curve order = 262567, Subgroup order n = 262567, Cofactor h = 1
# Candidate 262153 successful!
#
# --- Bit size 20 ---
#
#
# Trying candidate prime: 524341
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524341: Curve order = 524368, Subgroup order n = 2521, Cofactor h = 208
# Skipping candidate 524341: subgroup cofactor too large (h = 208).
#
# Trying candidate prime: 524347
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524347: Curve order = 524727, Subgroup order n = 8329, Cofactor h = 63
# Skipping candidate 524347: subgroup cofactor too large (h = 63).
#
# Trying candidate prime: 524353
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524353: Curve order = 525252, Subgroup order n = 37, Cofactor h = 14196
# Skipping candidate 524353: subgroup cofactor too large (h = 14196).
#
# Trying candidate prime: 524389
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524389: Curve order = 525733, Subgroup order n = 1093, Cofactor h = 481
# Skipping candidate 524389: subgroup cofactor too large (h = 481).
#
# Trying candidate prime: 524413
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524413: Curve order = 523407, Subgroup order n = 174469, Cofactor h = 3
# Skipping candidate 524413: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 524497
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524497: Curve order = 525819, Subgroup order n = 73, Cofactor h = 7203
# Skipping candidate 524497: subgroup cofactor too large (h = 7203).
#
# Trying candidate prime: 524509
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524509: Curve order = 525616, Subgroup order n = 19, Cofactor h = 27664
# Skipping candidate 524509: subgroup cofactor too large (h = 27664).
#
# Trying candidate prime: 524521
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524521: Curve order = 524100, Subgroup order n = 1747, Cofactor h = 300
# Skipping candidate 524521: subgroup cofactor too large (h = 300).
#
# Trying candidate prime: 524593
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524593: Curve order = 525259, Subgroup order n = 75037, Cofactor h = 7
# Skipping candidate 524593: subgroup cofactor too large (h = 7).
#
# Trying candidate prime: 524599
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524599: Curve order = 525153, Subgroup order n = 907, Cofactor h = 579
# Skipping candidate 524599: subgroup cofactor too large (h = 579).
#
# Trying candidate prime: 524683
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524683: Curve order = 523236, Subgroup order n = 6229, Cofactor h = 84
# Skipping candidate 524683: subgroup cofactor too large (h = 84).
#
# Trying candidate prime: 524701
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524701: Curve order = 524748, Subgroup order n = 6247, Cofactor h = 84
# Skipping candidate 524701: subgroup cofactor too large (h = 84).
#
# Trying candidate prime: 524707
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524707: Curve order = 524839, Subgroup order n = 10711, Cofactor h = 49
# Skipping candidate 524707: subgroup cofactor too large (h = 49).
#
# Trying candidate prime: 524731
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524731: Curve order = 524251, Subgroup order n = 823, Cofactor h = 637
# Skipping candidate 524731: subgroup cofactor too large (h = 637).
#
# Trying candidate prime: 524743
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524743: Curve order = 524551, Subgroup order n = 16921, Cofactor h = 31
# Skipping candidate 524743: subgroup cofactor too large (h = 31).
#
# Trying candidate prime: 524803
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524803: Curve order = 524916, Subgroup order n = 2083, Cofactor h = 252
# Skipping candidate 524803: subgroup cofactor too large (h = 252).
#
# Trying candidate prime: 524827
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524827: Curve order = 526204, Subgroup order n = 18793, Cofactor h = 28
# Skipping candidate 524827: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 524857
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524857: Curve order = 523497, Subgroup order n = 433, Cofactor h = 1209
# Skipping candidate 524857: subgroup cofactor too large (h = 1209).
#
# Trying candidate prime: 524863
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524863: Curve order = 525252, Subgroup order n = 37, Cofactor h = 14196
# Skipping candidate 524863: subgroup cofactor too large (h = 14196).
#
# Trying candidate prime: 524869
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524869: Curve order = 525837, Subgroup order n = 139, Cofactor h = 3783
# Skipping candidate 524869: subgroup cofactor too large (h = 3783).
#
# Trying candidate prime: 524893
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524893: Curve order = 525061, Subgroup order n = 5413, Cofactor h = 97
# Skipping candidate 524893: subgroup cofactor too large (h = 97).
#
# Trying candidate prime: 524899
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524899: Curve order = 526108, Subgroup order n = 1087, Cofactor h = 484
# Skipping candidate 524899: subgroup cofactor too large (h = 484).
#
# Trying candidate prime: 524941
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524941: Curve order = 526359, Subgroup order n = 175453, Cofactor h = 3
# Skipping candidate 524941: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 524947
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524947: Curve order = 523569, Subgroup order n = 877, Cofactor h = 597
# Skipping candidate 524947: subgroup cofactor too large (h = 597).
#
# Trying candidate prime: 524959
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524959: Curve order = 525787, Subgroup order n = 27673, Cofactor h = 19
# Skipping candidate 524959: subgroup cofactor too large (h = 19).
#
# Trying candidate prime: 524971
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524971: Curve order = 524181, Subgroup order n = 229, Cofactor h = 2289
# Skipping candidate 524971: subgroup cofactor too large (h = 2289).
#
# Trying candidate prime: 524983
# p is large; point counting may be slow. (This may take a while...)
# Candidate 524983: Curve order = 524356, Subgroup order n = 307, Cofactor h = 1708
# Skipping candidate 524983: subgroup cofactor too large (h = 1708).
#
# Trying candidate prime: 525001
# p is large; point counting may be slow. (This may take a while...)
# Candidate 525001: Curve order = 524079, Subgroup order n = 58231, Cofactor h = 9
# Skipping candidate 525001: subgroup cofactor too large (h = 9).
#
# Trying candidate prime: 525013
# p is large; point counting may be slow. (This may take a while...)
# Candidate 525013: Curve order = 524956, Subgroup order n = 3547, Cofactor h = 148
# Skipping candidate 525013: subgroup cofactor too large (h = 148).
#
# Trying candidate prime: 525043
# p is large; point counting may be slow. (This may take a while...)
# Candidate 525043: Curve order = 524269, Subgroup order n = 524269, Cofactor h = 1
# Candidate 525043 successful!
#
# --- Bit size 21 ---
#
#
# Trying candidate prime: 1048609
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048609: Curve order = 1049412, Subgroup order n = 31, Cofactor h = 33852
# Skipping candidate 1048609: subgroup cofactor too large (h = 33852).
#
# Trying candidate prime: 1048627
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048627: Curve order = 1048572, Subgroup order n = 73, Cofactor h = 14364
# Skipping candidate 1048627: subgroup cofactor too large (h = 14364).
#
# Trying candidate prime: 1048633
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048633: Curve order = 1050091, Subgroup order n = 2239, Cofactor h = 469
# Skipping candidate 1048633: subgroup cofactor too large (h = 469).
#
# Trying candidate prime: 1048681
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048681: Curve order = 1048896, Subgroup order n = 607, Cofactor h = 1728
# Skipping candidate 1048681: subgroup cofactor too large (h = 1728).
#
# Trying candidate prime: 1048717
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048717: Curve order = 1047088, Subgroup order n = 9349, Cofactor h = 112
# Skipping candidate 1048717: subgroup cofactor too large (h = 112).
#
# Trying candidate prime: 1048759
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048759: Curve order = 1049391, Subgroup order n = 16657, Cofactor h = 63
# Skipping candidate 1048759: subgroup cofactor too large (h = 63).
#
# Trying candidate prime: 1048783
# p is large; point counting may be slow. (This may take a while...)
# Candidate 1048783: Curve order = 1050337, Subgroup order n = 1050337, Cofactor h = 1
# Candidate 1048783 successful!
#
# --- Bit size 22 ---
#
#
# Trying candidate prime: 2097169
# p is large; point counting may be slow. (This may take a while...)
# Candidate 2097169: Curve order = 2097921, Subgroup order n = 99901, Cofactor h = 21
# Skipping candidate 2097169: subgroup cofactor too large (h = 21).
#
# Trying candidate prime: 2097211
# p is large; point counting may be slow. (This may take a while...)
# Candidate 2097211: Curve order = 2098699, Subgroup order n = 2098699, Cofactor h = 1
# Candidate 2097211 successful!
#
# --- Bit size 23 ---
#
#
# Trying candidate prime: 4194319
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194319: Curve order = 4198188, Subgroup order n = 349849, Cofactor h = 12
# Skipping candidate 4194319: subgroup cofactor too large (h = 12).
#
# Trying candidate prime: 4194397
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194397: Curve order = 4190907, Subgroup order n = 199567, Cofactor h = 21
# Skipping candidate 4194397: subgroup cofactor too large (h = 21).
#
# Trying candidate prime: 4194403
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194403: Curve order = 4198131, Subgroup order n = 1801, Cofactor h = 2331
# Skipping candidate 4194403: subgroup cofactor too large (h = 2331).
#
# Trying candidate prime: 4194409
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194409: Curve order = 4198287, Subgroup order n = 20887, Cofactor h = 201
# Skipping candidate 4194409: subgroup cofactor too large (h = 201).
#
# Trying candidate prime: 4194433
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194433: Curve order = 4197619, Subgroup order n = 7759, Cofactor h = 541
# Skipping candidate 4194433: subgroup cofactor too large (h = 541).
#
# Trying candidate prime: 4194439
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194439: Curve order = 4197172, Subgroup order n = 149899, Cofactor h = 28
# Skipping candidate 4194439: subgroup cofactor too large (h = 28).
#
# Trying candidate prime: 4194451
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194451: Curve order = 4196479, Subgroup order n = 1231, Cofactor h = 3409
# Skipping candidate 4194451: subgroup cofactor too large (h = 3409).
#
# Trying candidate prime: 4194493
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194493: Curve order = 4196241, Subgroup order n = 1549, Cofactor h = 2709
# Skipping candidate 4194493: subgroup cofactor too large (h = 2709).
#
# Trying candidate prime: 4194511
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194511: Curve order = 4196901, Subgroup order n = 1398967, Cofactor h = 3
# Skipping candidate 4194511: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 4194523
# p is large; point counting may be slow. (This may take a while...)
# Candidate 4194523: Curve order = 4197601, Subgroup order n = 4197601, Cofactor h = 1
# Candidate 4194523 successful!
#
# --- Bit size 24 ---
#
#
# Trying candidate prime: 8388619
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388619: Curve order = 8384692, Subgroup order n = 10861, Cofactor h = 772
# Skipping candidate 8388619: subgroup cofactor too large (h = 772).
#
# Trying candidate prime: 8388637
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388637: Curve order = 8394412, Subgroup order n = 4363, Cofactor h = 1924
# Skipping candidate 8388637: subgroup cofactor too large (h = 1924).
#
# Trying candidate prime: 8388673
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388673: Curve order = 8386429, Subgroup order n = 2287, Cofactor h = 3667
# Skipping candidate 8388673: subgroup cofactor too large (h = 3667).
#
# Trying candidate prime: 8388691
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388691: Curve order = 8391513, Subgroup order n = 2089, Cofactor h = 4017
# Skipping candidate 8388691: subgroup cofactor too large (h = 4017).
#
# Trying candidate prime: 8388697
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388697: Curve order = 8383899, Subgroup order n = 8443, Cofactor h = 993
# Skipping candidate 8388697: subgroup cofactor too large (h = 993).
#
# Trying candidate prime: 8388733
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388733: Curve order = 8383921, Subgroup order n = 373, Cofactor h = 22477
# Skipping candidate 8388733: subgroup cofactor too large (h = 22477).
#
# Trying candidate prime: 8388739
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388739: Curve order = 8382997, Subgroup order n = 1197571, Cofactor h = 7
# Skipping candidate 8388739: subgroup cofactor too large (h = 7).
#
# Trying candidate prime: 8388763
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388763: Curve order = 8390109, Subgroup order n = 421, Cofactor h = 19929
# Skipping candidate 8388763: subgroup cofactor too large (h = 19929).
#
# Trying candidate prime: 8388811
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388811: Curve order = 8394283, Subgroup order n = 86539, Cofactor h = 97
# Skipping candidate 8388811: subgroup cofactor too large (h = 97).
#
# Trying candidate prime: 8388841
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388841: Curve order = 8391859, Subgroup order n = 32401, Cofactor h = 259
# Skipping candidate 8388841: subgroup cofactor too large (h = 259).
#
# Trying candidate prime: 8388901
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388901: Curve order = 8388604, Subgroup order n = 337, Cofactor h = 24892
# Skipping candidate 8388901: subgroup cofactor too large (h = 24892).
#
# Trying candidate prime: 8388949
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8388949: Curve order = 8386923, Subgroup order n = 147139, Cofactor h = 57
# Skipping candidate 8388949: subgroup cofactor too large (h = 57).
#
# Trying candidate prime: 8389027
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8389027: Curve order = 8388549, Subgroup order n = 23899, Cofactor h = 351
# Skipping candidate 8389027: subgroup cofactor too large (h = 351).
#
# Trying candidate prime: 8389039
# p is large; point counting may be slow. (This may take a while...)
# Candidate 8389039: Curve order = 8387557, Subgroup order n = 8387557, Cofactor h = 1
# Candidate 8389039 successful!
#
# --- Bit size 25 ---
#
#
# Trying candidate prime: 16777291
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777291: Curve order = 16769100, Subgroup order n = 55897, Cofactor h = 300
# Skipping candidate 16777291: subgroup cofactor too large (h = 300).
#
# Trying candidate prime: 16777333
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777333: Curve order = 16771447, Subgroup order n = 19801, Cofactor h = 847
# Skipping candidate 16777333: subgroup cofactor too large (h = 847).
#
# Trying candidate prime: 16777381
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777381: Curve order = 16779175, Subgroup order n = 95881, Cofactor h = 175
# Skipping candidate 16777381: subgroup cofactor too large (h = 175).
#
# Trying candidate prime: 16777441
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777441: Curve order = 16778853, Subgroup order n = 6829, Cofactor h = 2457
# Skipping candidate 16777441: subgroup cofactor too large (h = 2457).
#
# Trying candidate prime: 16777447
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777447: Curve order = 16769959, Subgroup order n = 9733, Cofactor h = 1723
# Skipping candidate 16777447: subgroup cofactor too large (h = 1723).
#
# Trying candidate prime: 16777507
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777507: Curve order = 16782507, Subgroup order n = 547, Cofactor h = 30681
# Skipping candidate 16777507: subgroup cofactor too large (h = 30681).
#
# Trying candidate prime: 16777531
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777531: Curve order = 16775389, Subgroup order n = 8317, Cofactor h = 2017
# Skipping candidate 16777531: subgroup cofactor too large (h = 2017).
#
# Trying candidate prime: 16777597
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777597: Curve order = 16775319, Subgroup order n = 1249, Cofactor h = 13431
# Skipping candidate 16777597: subgroup cofactor too large (h = 13431).
#
# Trying candidate prime: 16777633
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777633: Curve order = 16784467, Subgroup order n = 126199, Cofactor h = 133
# Skipping candidate 16777633: subgroup cofactor too large (h = 133).
#
# Trying candidate prime: 16777639
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777639: Curve order = 16785499, Subgroup order n = 5527, Cofactor h = 3037
# Skipping candidate 16777639: subgroup cofactor too large (h = 3037).
#
# Trying candidate prime: 16777669
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777669: Curve order = 16785853, Subgroup order n = 6871, Cofactor h = 2443
# Skipping candidate 16777669: subgroup cofactor too large (h = 2443).
#
# Trying candidate prime: 16777681
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777681: Curve order = 16785639, Subgroup order n = 143467, Cofactor h = 117
# Skipping candidate 16777681: subgroup cofactor too large (h = 117).
#
# Trying candidate prime: 16777699
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777699: Curve order = 16775689, Subgroup order n = 487, Cofactor h = 34447
# Skipping candidate 16777699: subgroup cofactor too large (h = 34447).
#
# Trying candidate prime: 16777711
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777711: Curve order = 16773843, Subgroup order n = 5591281, Cofactor h = 3
# Skipping candidate 16777711: subgroup cofactor too large (h = 3).
#
# Trying candidate prime: 16777723
# p is large; point counting may be slow. (This may take a while...)
# Candidate 16777723: Curve order = 16773667, Subgroup order n = 16773667, Cofactor h = 1
# Candidate 16777723 successful!
#
# All done!
# Total successful runs: 25
